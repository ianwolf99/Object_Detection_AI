# %%
import tensorflow as tf

# Display the version
print(tf.__version__)

# other imports
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalMaxPooling2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
# Out:
# 2.17.1

# %%
# Load in the data
cifar10 = tf.keras.datasets.cifar10

# Distribute it to train and test set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)

# %%
# Reduce pixel values
x_train, x_test = x_train / 255.0, x_test / 255.0

# flatten the label values
y_train, y_test = y_train.flatten(), y_test.flatten()

# %%
# visualize data by plotting images
fig, ax = plt.subplots(10, 10)
k = 0

for i in range(10):
	for j in range(10):
		ax[i][j].imshow(x_train[k], aspect='auto')
		k += 1

plt.show()

# %%
# number of classes
K = len(set(y_train))

# calculate total number of classes
# for output layer
print("number of classes:", K)

# Build the model using the functional API
# input layer
i = Input(shape=x_train[0].shape)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
x = Dropout(0.2)(x)

# Hidden layer
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)

# last hidden layer i.e.. output layer
x = Dense(K, activation='softmax')(x)

model = Model(i, x)

# model description
model.summary()
# Out:
# number of classes: 10
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │          10,250 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,397,226 (9.14 MB)
#  Trainable params: 2,396,330 (9.14 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
# Compile
model.compile(optimizer='adam',
			loss='sparse_categorical_crossentropy',
			metrics=['accuracy'])

# %%
# Fit
r = model.fit(
x_train, y_train, validation_data=(x_test, y_test), epochs=50)
# Out:
# Epoch 1/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 28s 11ms/step - accuracy: 0.4653 - loss: 1.6991 - val_accuracy: 0.6536 - val_loss: 1.0260
# Epoch 2/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - accuracy: 0.7051 - loss: 0.8562 - val_accuracy: 0.7390 - val_loss: 0.7684
# Epoch 3/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.7661 - loss: 0.6720 - val_accuracy: 0.7211 - val_loss: 0.8497
# Epoch 4/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8072 - loss: 0.5526 - val_accuracy: 0.7790 - val_loss: 0.6749
# Epoch 5/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8388 - loss: 0.4767 - val_accuracy: 0.7895 - val_loss: 0.6365
# Epoch 6/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8668 - loss: 0.3870 - val_accuracy: 0.8058 - val_loss: 0.6113
# Epoch 7/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8890 - loss: 0.3177 - val_accuracy: 0.8165 - val_loss: 0.5965
# Epoch 8/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9041 - loss: 0.2734 - val_accuracy: 0.8026 - val_loss: 0.6477
# Epoch 9/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9233 - loss: 0.2273 - val_accuracy: 0.8133 - val_loss: 0.6451
# Epoch 10/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9320 - loss: 0.1946 - val_accuracy: 0.8139 - val_loss: 0.6507
# Epoch 11/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9414 - loss: 0.1723 - val_accuracy: 0.8197 - val_loss: 0.6947
# Epoch 12/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9479 - loss: 0.1546 - val_accuracy: 0.8240 - val_loss: 0.6831
# Epoch 13/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9494 - loss: 0.1469 - val_accuracy: 0.8173 - val_loss: 0.7283
# Epoch 14/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9576 - loss: 0.1285 - val_accuracy: 0.8246 - val_loss: 0.7342
# Epoch 15/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9587 - loss: 0.1196 - val_accuracy: 0.8354 - val_loss: 0.6758
# Epoch 16/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9626 - loss: 0.1119 - val_accuracy: 0.8308 - val_loss: 0.7470
# Epoch 17/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9647 - loss: 0.1036 - val_accuracy: 0.8218 - val_loss: 0.7779
# Epoch 18/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9661 - loss: 0.0996 - val_accuracy: 0.8316 - val_loss: 0.7591
# Epoch 19/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9677 - loss: 0.0955 - val_accuracy: 0.8419 - val_loss: 0.7189
# Epoch 20/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9742 - loss: 0.0776 - val_accuracy: 0.8371 - val_loss: 0.7956
# Epoch 21/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9720 - loss: 0.0853 - val_accuracy: 0.8277 - val_loss: 0.8236
# Epoch 22/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9744 - loss: 0.0810 - val_accuracy: 0.8334 - val_loss: 0.8231
# Epoch 23/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9752 - loss: 0.0727 - val_accuracy: 0.8241 - val_loss: 0.8784
# Epoch 24/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9736 - loss: 0.0787 - val_accuracy: 0.8321 - val_loss: 0.7465
# Epoch 25/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9778 - loss: 0.0676 - val_accuracy: 0.8326 - val_loss: 0.7770
# Epoch 26/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9759 - loss: 0.0721 - val_accuracy: 0.8319 - val_loss: 0.7559
# Epoch 27/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9781 - loss: 0.0663 - val_accuracy: 0.8301 - val_loss: 0.7622
# Epoch 28/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9786 - loss: 0.0650 - val_accuracy: 0.8358 - val_loss: 0.7534
# Epoch 29/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9817 - loss: 0.0550 - val_accuracy: 0.8333 - val_loss: 0.8521
# Epoch 30/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9796 - loss: 0.0638 - val_accuracy: 0.8375 - val_loss: 0.7517
# Epoch 31/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9823 - loss: 0.0559 - val_accuracy: 0.8371 - val_loss: 0.8026
# Epoch 32/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9824 - loss: 0.0537 - val_accuracy: 0.8315 - val_loss: 0.8266
# Epoch 33/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9824 - loss: 0.0545 - val_accuracy: 0.8500 - val_loss: 0.7221
# Epoch 34/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9836 - loss: 0.0517 - val_accuracy: 0.8431 - val_loss: 0.7502
# Epoch 35/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9819 - loss: 0.0545 - val_accuracy: 0.8380 - val_loss: 0.7985
# Epoch 36/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9844 - loss: 0.0491 - val_accuracy: 0.8381 - val_loss: 0.8708
# Epoch 37/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9832 - loss: 0.0539 - val_accuracy: 0.8449 - val_loss: 0.8367
# Epoch 38/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9865 - loss: 0.0439 - val_accuracy: 0.8382 - val_loss: 0.8109
# Epoch 39/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9855 - loss: 0.0459 - val_accuracy: 0.8385 - val_loss: 0.8972
# Epoch 40/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9853 - loss: 0.0491 - val_accuracy: 0.8380 - val_loss: 0.8768
# Epoch 41/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9860 - loss: 0.0447 - val_accuracy: 0.8434 - val_loss: 0.8532
# Epoch 42/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9858 - loss: 0.0461 - val_accuracy: 0.8377 - val_loss: 0.9624
# Epoch 43/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9862 - loss: 0.0439 - val_accuracy: 0.8402 - val_loss: 0.8089
# Epoch 44/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9862 - loss: 0.0431 - val_accuracy: 0.8394 - val_loss: 0.8459
# Epoch 45/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9870 - loss: 0.0411 - val_accuracy: 0.8465 - val_loss: 0.8658
# Epoch 46/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9873 - loss: 0.0416 - val_accuracy: 0.8454 - val_loss: 0.8332
# Epoch 47/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9873 - loss: 0.0404 - val_accuracy: 0.8349 - val_loss: 0.8760
# Epoch 48/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9871 - loss: 0.0395 - val_accuracy: 0.8498 - val_loss: 0.9170
# Epoch 49/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9883 - loss: 0.0370 - val_accuracy: 0.8418 - val_loss: 0.9287
# Epoch 50/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9874 - loss: 0.0391 - val_accuracy: 0.8331 - val_loss: 1.0391

# %%
# Fit with data augmentation
# Note: if you run this AFTER calling
# the previous model.fit()
# it will CONTINUE training where it left off
batch_size = 32
data_generator = tf.keras.preprocessing.image.ImageDataGenerator(
width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

train_generator = data_generator.flow(x_train, y_train, batch_size)
steps_per_epoch = x_train.shape[0] // batch_size

r = model.fit(train_generator, validation_data=(x_test, y_test),
			steps_per_epoch=steps_per_epoch, epochs=50)
# Out:
# Epoch 1/50
#    1/1562 ━━━━━━━━━━━━━━━━━━━━ 4:20 167ms/step - accuracy: 0.8438 - loss: 1.1729
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.8130 - loss: 0.6133 - val_accuracy: 0.8419 - val_loss: 0.5136
# Epoch 2/50
#    1/1562 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.9062 - loss: 0.4077
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 623us/step - accuracy: 0.9062 - loss: 0.4077 - val_accuracy: 0.8413 - val_loss: 0.5110
# Epoch 3/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 80s 25ms/step - accuracy: 0.8609 - loss: 0.4317 - val_accuracy: 0.8518 - val_loss: 0.4656
# Epoch 4/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 455us/step - accuracy: 0.9062 - loss: 0.1953 - val_accuracy: 0.8523 - val_loss: 0.4644
# Epoch 5/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.8675 - loss: 0.3994 - val_accuracy: 0.8541 - val_loss: 0.4587
# Epoch 6/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 458us/step - accuracy: 0.7500 - loss: 0.6499 - val_accuracy: 0.8544 - val_loss: 0.4552
# Epoch 7/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 39s 25ms/step - accuracy: 0.8752 - loss: 0.3712 - val_accuracy: 0.8501 - val_loss: 0.4705
# Epoch 8/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 825us/step - accuracy: 0.8125 - loss: 0.4802 - val_accuracy: 0.8517 - val_loss: 0.4668
# Epoch 9/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 40s 26ms/step - accuracy: 0.8808 - loss: 0.3495 - val_accuracy: 0.8531 - val_loss: 0.4591
# Epoch 10/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 489us/step - accuracy: 0.8750 - loss: 0.4785 - val_accuracy: 0.8538 - val_loss: 0.4573
# Epoch 11/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 40s 25ms/step - accuracy: 0.8835 - loss: 0.3470 - val_accuracy: 0.8606 - val_loss: 0.4280
# Epoch 12/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 445us/step - accuracy: 0.8750 - loss: 0.5400 - val_accuracy: 0.8609 - val_loss: 0.4278
# Epoch 13/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 40s 26ms/step - accuracy: 0.8927 - loss: 0.3207 - val_accuracy: 0.8649 - val_loss: 0.4491
# Epoch 14/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 467us/step - accuracy: 0.9062 - loss: 0.2772 - val_accuracy: 0.8648 - val_loss: 0.4495
# Epoch 15/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 42s 27ms/step - accuracy: 0.8930 - loss: 0.3183 - val_accuracy: 0.8594 - val_loss: 0.4552
# Epoch 16/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 825us/step - accuracy: 0.9375 - loss: 0.1654 - val_accuracy: 0.8592 - val_loss: 0.4544
# Epoch 17/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 40s 26ms/step - accuracy: 0.8970 - loss: 0.3023 - val_accuracy: 0.8619 - val_loss: 0.4436
# Epoch 18/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 825us/step - accuracy: 0.8125 - loss: 0.5979 - val_accuracy: 0.8617 - val_loss: 0.4445
# Epoch 19/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 82s 26ms/step - accuracy: 0.8979 - loss: 0.2987 - val_accuracy: 0.8615 - val_loss: 0.4385
# Epoch 20/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 825us/step - accuracy: 0.9688 - loss: 0.1355 - val_accuracy: 0.8616 - val_loss: 0.4397
# Epoch 21/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 39s 25ms/step - accuracy: 0.9020 - loss: 0.2896 - val_accuracy: 0.8610 - val_loss: 0.4426
# Epoch 22/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 459us/step - accuracy: 0.8438 - loss: 0.3863 - val_accuracy: 0.8610 - val_loss: 0.4414
# Epoch 23/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 40s 25ms/step - accuracy: 0.9069 - loss: 0.2777 - val_accuracy: 0.8575 - val_loss: 0.4455
# Epoch 24/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 576us/step - accuracy: 0.8750 - loss: 0.2511 - val_accuracy: 0.8585 - val_loss: 0.4429
# Epoch 25/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.9067 - loss: 0.2733 - val_accuracy: 0.8638 - val_loss: 0.4553
# Epoch 26/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 455us/step - accuracy: 0.8750 - loss: 0.2796 - val_accuracy: 0.8634 - val_loss: 0.4585
# Epoch 27/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 40s 26ms/step - accuracy: 0.9072 - loss: 0.2721 - val_accuracy: 0.8673 - val_loss: 0.4259
# Epoch 28/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 457us/step - accuracy: 0.9375 - loss: 0.1795 - val_accuracy: 0.8666 - val_loss: 0.4264
# Epoch 29/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 82s 26ms/step - accuracy: 0.9125 - loss: 0.2615 - val_accuracy: 0.8632 - val_loss: 0.4724
# Epoch 30/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 826us/step - accuracy: 0.9688 - loss: 0.0848 - val_accuracy: 0.8631 - val_loss: 0.4725
# Epoch 31/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 79s 25ms/step - accuracy: 0.9105 - loss: 0.2580 - val_accuracy: 0.8727 - val_loss: 0.4164
# Epoch 32/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 463us/step - accuracy: 0.8438 - loss: 0.4136 - val_accuracy: 0.8722 - val_loss: 0.4173
# Epoch 33/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 40s 25ms/step - accuracy: 0.9150 - loss: 0.2505 - val_accuracy: 0.8611 - val_loss: 0.4427
# Epoch 34/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 829us/step - accuracy: 0.9375 - loss: 0.2120 - val_accuracy: 0.8615 - val_loss: 0.4421
# Epoch 35/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.9147 - loss: 0.2491 - val_accuracy: 0.8732 - val_loss: 0.4029
# Epoch 36/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 828us/step - accuracy: 0.8750 - loss: 0.3189 - val_accuracy: 0.8727 - val_loss: 0.4044
# Epoch 37/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 82s 27ms/step - accuracy: 0.9188 - loss: 0.2346 - val_accuracy: 0.8585 - val_loss: 0.4654
# Epoch 38/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 598us/step - accuracy: 1.0000 - loss: 0.0534 - val_accuracy: 0.8566 - val_loss: 0.4660
# Epoch 39/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 80s 26ms/step - accuracy: 0.9206 - loss: 0.2309 - val_accuracy: 0.8691 - val_loss: 0.4327
# Epoch 40/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 451us/step - accuracy: 0.9375 - loss: 0.1319 - val_accuracy: 0.8691 - val_loss: 0.4345
# Epoch 41/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.9251 - loss: 0.2208 - val_accuracy: 0.8740 - val_loss: 0.4174
# Epoch 42/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 460us/step - accuracy: 1.0000 - loss: 0.0769 - val_accuracy: 0.8727 - val_loss: 0.4199
# Epoch 43/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 40s 25ms/step - accuracy: 0.9260 - loss: 0.2233 - val_accuracy: 0.8718 - val_loss: 0.4363
# Epoch 44/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 591us/step - accuracy: 0.9375 - loss: 0.2009 - val_accuracy: 0.8710 - val_loss: 0.4378
# Epoch 45/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 40s 26ms/step - accuracy: 0.9279 - loss: 0.2122 - val_accuracy: 0.8759 - val_loss: 0.4287
# Epoch 46/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 826us/step - accuracy: 0.9688 - loss: 0.1283 - val_accuracy: 0.8758 - val_loss: 0.4293
# Epoch 47/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 40s 26ms/step - accuracy: 0.9249 - loss: 0.2260 - val_accuracy: 0.8734 - val_loss: 0.4278
# Epoch 48/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 825us/step - accuracy: 0.9688 - loss: 0.1631 - val_accuracy: 0.8733 - val_loss: 0.4296
# Epoch 49/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 82s 27ms/step - accuracy: 0.9297 - loss: 0.2075 - val_accuracy: 0.8781 - val_loss: 0.4560
# Epoch 50/50
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 1s 451us/step - accuracy: 0.9688 - loss: 0.0952 - val_accuracy: 0.8786 - val_loss: 0.4566

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='acc', color='red')
plt.plot(r.history['val_accuracy'], label='val_acc', color='green')
plt.legend()

# %%
# label mapping

labels = '''airplane automobile bird cat deerdog frog horseship truck'''.split()

# select the image from our test dataset
image_number = 6

# display the image
plt.imshow(x_test[image_number])

# load the image in an array
n = np.array(x_test[image_number])

# reshape it
p = n.reshape(1, 32, 32, 3)

# pass in the network for prediction and
# save the predicted label
predicted_label = labels[model.predict(p).argmax()]

# load the original label
original_label = labels[y_test[image_number]]

# display the result
print("Original label is {} and predicted label is {}".format(
	original_label, predicted_label))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Original label is automobile and predicted label is automobile

# %%
# save the model
model.save('cifar10classification.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
